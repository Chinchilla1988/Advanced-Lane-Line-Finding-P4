# %%
# %matplotlib inline
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image=cv2.imread('Download.png')
imagek=image
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
print(image.shape)
# Out:
# (223, 378, 3)

# %%
x0,x1=image.shape[1]*.15,image.shape[1]*.35
x2,x3=image.shape[1]*.67,image.shape[1]*.93
y0,y1=image.shape[0]*.9,image.shape[0]*.6
y2,y3=image.shape[0]*.6,image.shape[0]*.9
plt.scatter(x=(x2), y=(y2), c='r', s=40)
plt.imshow(image)
pts1 = np.float32([[x1,y1],[x2,y2],[x0,y0],[x3,y3]])
pts2 = np.float32([[0,0],[image.shape[0],0],[0,image.shape[0]],[image.shape[1],image.shape[0]]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(image,M,(image.shape[1],image.shape[0]))

plt.scatter(x=(x0,x1,x2,x3), y=(y0,y1,y2,y3), c='r', s=40)

plt.figure(figsize=(12,6))
plt.imshow(image),plt.title('Input')

#plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.imshow(dst)
#plt.show()

# %%
print(dst.shape[0],dst.shape[1])
k=imagek.shape[1]
histogram = np.sum(dst[int(imagek.shape[0]/2):,:], axis=0)
plt.plot(histogram)
# Out:
# 223 378
# ...
